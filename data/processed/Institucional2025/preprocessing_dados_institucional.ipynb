# %% [markdown]
# # Processamento de dados Institucional

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from typing import List, Dict, Tuple

path_to_dir = '../../raw/Institucional2025_dados_raw/'
# Perguntas
df_dados_perguntas_raw = pd.read_csv(f'{path_to_dir}dados_institucional_perguntas.csv')
df_dados_info_perguntas_raw = pd.read_csv(f'{path_to_dir}dados_institucional_info_perguntas.csv')
df_dados_info_questionarios_raw = pd.read_csv(f'{path_to_dir}dados_institucional_info_questionarios.csv')
# Unidades
df_dados_unidades_raw = pd.read_csv(f'{path_to_dir}dados_institucional_unidades.csv')

# Pesquisa
df_dados_pesquisa_raw = pd.read_csv(f'{path_to_dir}dados_institucional_pesquisa.csv')

# %% [markdown]
# ## 2. Funções para descrição de dataframes

# %%
def get_possible_results(df: pd.DataFrame) -> Dict:
    ''' 
    Return:
    - data: Dictionary where the keys are the columns values and values are a list containing all possible values in a column. Order of appearance is preserved by .unique().
    
    '''
    cols = df.columns
    data = dict()

    for col in cols:
        data[col] = df[col].unique().tolist()

    return data

# %%
def remove_unnamed_columns(df: pd.DataFrame) -> pd.DataFrame:
    ''' 
    Laziness in manually processing data before transforming it into dataframes.

    Remove all the 'Unnamed' columns in a dataframe.
    '''
    return df.loc[:,~df.columns.str.contains('^Unnamed')]

# %%
def count_occurrences_by_column(df: pd.DataFrame,columns: List|None = None) -> Dict:
    columns_to_process = columns if columns is not None else df.columns

    occurrences = {}

    for col in columns_to_process:
        occurrences[col] = df[col].value_counts()

    return occurrences

# %% [markdown]
# ### 2.1 Testes

# %%
print(get_possible_results(remove_unnamed_columns(df_dados_info_perguntas_raw)))
# Out:
# {'Tipo_Perg': ['MsãoPDI', 'RsSc', 'PolPes', 'OrgGesInst', 'SustFin', 'CHC'], 'Grupo_de_Perguntas': ['Missão e Plano de Desenvolvimento Institucional', 'Responsabilidade Social', 'Políticas de Pessoal', 'Organização e Gestão da Instituição', 'Sustentabilidade Financeira', 'Complexo do Hospital de Clínicas (CHC-UFPR/Ebserh)']}

# %%
remove_unnamed_columns(df_dados_info_questionarios_raw)
# Out:
#    ID_QUESTIONARIO                                       QUESTIONARIO
# 0              644    Missão e Plano de Desenvolvimento Institucional
# 1              645                            Responsabilidade Social
# 2              646                               Políticas de Pessoal
# 3              647                Organização e Gestão da Instituição
# 4              648                        Sustentabilidade Financeira
# 5              649  Complexo do Hospital de Clínicas (CHC-UFPR/Ebs...

# %%
ocorrencias = count_occurrences_by_column(df_dados_pesquisa_raw)

for coluna, contagem in ocorrencias.items():
    print(f"--- Frequência: {coluna} ---")
    print(contagem.to_string())
    print("\n")
# Out:
# --- Frequência: ID_PESQUISA ---
# ID_PESQUISA
# 47185    210
# 47352    210
# 47730    210
# 47473    210
# 47769    204
# 47291    186
# 47343    140
# 47385    140
# 47243    140
# 47821    140
# 47187    140
# 46982    140
# 47384    140
# 47776    140
# 47061    140
# 47244    140
# 47360    140
# 47689    140
# 47808    140
# 47188    140
# 47729    140
# 47304    140
# 47085    140
# 47739    140
# 47169    140
# 47090    140
# 47286    140
# 47851      7
# 47514      2
#
#
# --- Frequência: ID_QUESTIONARIO ---
# ID_QUESTIONARIO
# 649    13332
# 647    11019
# 644     8118
# 646     7446
# 645     6707
# 648     3657
#
#
# --- Frequência: QUESTIONARIO ---
# QUESTIONARIO
# Complexo do Hospital de Clínicas (CHC-UFPR/Ebserh)    13332
# Organização e Gestão da Instituição                   11019
# Missão e Plano de Desenvolvimento Institucional        8118
# Políticas de Pessoal                                   7446
# Responsabilidade Social                                6707
# Sustentabilidade Financeira                            3657
#
#
# --- Frequência: ID_PERGUNTA ---
# ID_PERGUNTA
# 1982    753
# 2004    752
# 1995    749
# 2005    748
# 1984    748
# 1994    747
# 1996    747
# 2002    747
# 2006    747
# 1983    746
# 2009    745
# 1998    745
# 1997    745
# 1999    744
# 2013    744
# 2007    743
# 2011    743
# 2001    743
# 2008    743
# 1986    742
# 2022    741
# 2021    741
# 2012    741
# 2000    740
# 2015    740
# 2010    740
# 2018    739
# 1985    738
# 2024    738
# 1988    738
# 2019    736
# 2028    735
# 2020    735
# 2017    735
# 2025    735
# 2029    735
# 2033    735
# 1987    734
# 2031    734
# 1989    733
# 2027    733
# 2016    731
# 2034    731
# 2035    730
# 1991    730
# 1990    729
# 1992    727
# 2036    727
# 2026    724
# 2023    721
# 2039    700
# 2038    695
# 2042    676
# 2041    673
# 2040    670
# 2049    667
# 2052    666
# 2045    665
# 2056    665
# 2044    665
# 2043    664
# 2047    663
# 2051    662
# 2057    661
# 2054    659
# 2053    659
# 2046    658
# 2055    657
# 2050    655
# 2048    652
#
#
# --- Frequência: PERGUNTA ---
# PERGUNTA
# As políticas de controle orçamentário e de alocação de recursos refletem o planejamento institucional.                                                                                                                                                                                                                                          1399
# A missão* da UFPR é coerente com as necessidades locais e regionais.                                                                                                                                                                                                                                                                             753
# As necessidades institucionais de pessoal estão bem dimensionadas e o quadro é adequado às demandas da minha unidade de lotação.                                                                                                                                                                                                                 752
# Estão implantadas iniciativas institucionais e/ou setoriais que promovem a proteção ambiental, como a correta separação de lixo, a destinação responsável de resíduos, o aproveitamento de recursos naturais, o tratamento de efluentes, e/ou outras iniciativas.\t\t                                                                            749
# Enquanto servidor (docente ou técnico), tenho familiaridade com o Plano de Desenvolvimento Institucional (PDI)* da UFPR.\t\t                                                                                                                                                                                                                     748
# O processo de movimentação interna é objetivo e transparente, permitindo a adaptação e acolhimento dos servidores, consideradas suas habilidades e conhecimentos, para a melhor ocupação das vagas.                                                                                                                                              748
# A relação da UFPR com os setores público e privado, com o mercado de trabalho e com instituições sociais, culturais e educativas são suficientes e cooperam para o desenvolvimento institucional.                                                                                                                                                747
# Os procedimentos para mobilidade de pessoal (redistribuição, colaboração técnica, exercício provisório, requisição, cessão e remoção) estão claros na instituição.                                                                                                                                                                               747
# As ações de inclusão e diversidade social são efetivas na instituição*.                                                                                                                                                                                                                                                                          747
# Os projetos institucionais e/ou setoriais de incentivo ao uso consciente de água, energia elétrica e suprimentos (materiais de expediente, laboratoriais, limpeza e higienização, proteção e segurança etc.) são eficazes.\t\t                                                                                                                   747
# Percebe-se que a sociedade reconhece a relevância da UFPR na construção de uma sociedade inclusiva, equânime e solidária, reflexo de sua missão* e valores**.                                                                                                                                                                                    746
# A universidade contribui efetivamente com a criação de conhecimentos para o desenvolvimento científico, técnico e profissional do país.                                                                                                                                                                                                          745
# A instituição incentiva e propicia o aperfeiçoamento profissional e cidadão e a formação continuada dos servidores docentes e técnicos.                                                                                                                                                                                                          745
# O planejamento setorial, com o apoio da administração central da UFPR, considera a necessidade de adaptações físicas para a melhoria da acessibilidade nos ambientes internos e nos campi.                                                                                                                                                       745
# As ações de prevenção e promoção da segurança no trabalho, incluindo a fiscalização das condições de trabalho físicas e do ambiente, são efetivas na UFPR.                                                                                                                                                                                       744
# São notórios os programas e projetos de extensão, bem como projetos institucionais que colaboram com o desenvolvimento econômico e social da região.                                                                                                                                                                                             744
# São visíveis as ações que fortalecem e preservam a memória cultural, a produção artística e o patrimônio cultural da instituição.                                                                                                                                                                                                                743
# Os servidores técnico-administrativos participam do levantamento e definição das necessidades de capacitação e qualificação para a elaboração anual do Plano de Desenvolvimento de Pessoas (PDP) da unidade.                                                                                                                                     743
# Os gestores respeitam as descrições legais dos diversos cargos técnico-administrativos em educação e alinham as metas institucionais às responsabilidades dos cargos.                                                                                                                                                                            743
# O processo de avaliação de desempenho dos servidores técnico-administrativos é transparente e organizado, e os resultados orientam os gestores na busca de soluções para a melhoria do desempenho das unidades.                                                                                                                                  743
# Os objetivos estratégicos do Plano de Desenvolvimento Institucional (PDI) para o quinquênio 2022-2026 estão alinhados à missão* e visão** da instituição.                                                                                                                                                                                        742
# São visíveis os movimentos de incentivo à inovação tecnológica por meio de parcerias.                                                                                                                                                                                                                                                            741
# A instituição acolhe e apoia aqueles que sofrem qualquer forma de violência* dentro do ambiente da universidade.                                                                                                                                                                                                                                 741
# As ações de promoção da saúde e qualidade de vida (acompanhamento, prevenção e assistência) são adequadas às necessidades institucionais.                                                                                                                                                                                                        741
# A universidade promove cursos e programas de formação inicial e continuada de docentes para a educação básica.                                                                                                                                                                                                                                   740
# O funcionamento dos colegiados de curso, plenárias departamentais, conselhos setoriais e conselhos superiores é transparente, autônomo e com representatividade de todos os segmentos da comunidade universitária nos processos decisórios.                                                                                                      740
# As normativas legais e institucionais estão claras e orientam os servidores no que se refere à obtenção de auxílios financeiros e licenças para desenvolvimento profissional.                                                                                                                                                                    740
# São aplicados mecanismos* efetivos de desburocratização e racionalização dos serviços, visando à otimização do trabalho e à agilidade no atendimento aos públicos.                                                                                                                                                                               739
# Percebo o envolvimento de diversos atores da unidade em que atuo na construção e revisão do Plano de Desenvolvimento Institucional (PDI).                                                                                                                                                                                                        738
# Há coerência entre o Plano de Desenvolvimento Institucional (PDI) e as ações institucionais de ensino, pesquisa, extensão, inovação, internacionalização e gestão.                                                                                                                                                                               738
# O apoio em tecnologias de informação e comunicação para as atividades de gestão acadêmica e administrativa é adequado à demanda institucional.                                                                                                                                                                                                   738
# Os gestores acadêmicos e administrativos (pró-reitores, diretores, chefias, coordenadores, superintendentes e equivalentes) estão adequadamente capacitados pela instituição para assumirem suas funções.                                                                                                                                        736
# As unidades gestoras conduzem a organização do teletrabalho de forma adequada, levando em consideração os objetivos do Programa de Gestão e Desempenho (PGD).                                                                                                                                                                                    735
# A instituição dá suporte à comunidade interna nas demandas de proteção do conhecimento, transferência de tecnologia e negociação da propriedade intelectual.                                                                                                                                                                                     735
# As atribuições e competências de cada unidade organizacional estão claras e organizadas em regimentos, e refletem a realidade da área.                                                                                                                                                                                                           735
# Há transparência na gestão e no planejamento da força de trabalho terceirizada.                                                                                                                                                                                                                                                                  735
# São organizadas e transparentes as políticas e normativas de gestão de suprimentos/materiais de consumo*.                                                                                                                                                                                                                                        735
# As políticas de captação e alocação de recursos são transparentes e amplamente disseminadas na instituição.                                                                                                                                                                                                                                      735
# Há articulação entre o Plano de Desenvolvimento Institucional (PDI) e o Projeto Pedagógico Institucional (PPI).                                                                                                                                                                                                                                  734
# As ações de diversidade e inclusão na universidade condizem com as metas estabelecidas no Plano de Desenvolvimento Institucional (PDI).                                                                                                                                                                                                          733
# São organizadas e transparentes as políticas e normativas de gestão de patrimônio.                                                                                                                                                                                                                                                               733
# A formalização de parcerias com captação de recursos externos e financiamentos produzem resultados efetivos nas atividades de ensino, pesquisa e extensão.                                                                                                                                                                                       731
# As decisões e documentações resultantes das sessões dos colegiados, plenárias e conselhos são apropriadas pela comunidade interna e guiam os processos de gestão institucional.                                                                                                                                                                  731
# As ações de preservação do meio-ambiente e de desenvolvimento sustentável na universidade estão em sintonia com as metas estabelecidas no Plano de Desenvolvimento Institucional (PDI).                                                                                                                                                          730
# As fundações gerenciam de forma transparente os recursos que recebem, provenientes de captação externa.                                                                                                                                                                                                                                          730
# As ações voltadas à memória, ao patrimônio cultural e à produção artística na universidade estão de acordo com as metas estabelecidas no Plano de Desenvolvimento Institucional (PDI).                                                                                                                                                           729
# O planejamento interno setorial, com metas e atividades claramente definidas, está alinhado aos objetivos estratégicos e módulos de ação traçados no Plano de Desenvolvimento Institucional (PDI).                                                                                                                                               727
# A transparência no gerenciamento das licitações e contratações para aquisições de materiais e serviços é prática da instituição.                                                                                                                                                                                                                 727
# A cultura empreendedora e de incubação de empresas é disseminada para toda a comunidade universitária.                                                                                                                                                                                                                                           724
# Enquanto servidor (docente ou técnico) lotado em campus/setor fora da sede, observo o diálogo entre a administração central e o campus/setor para garantir a integração e a implantação de projetos de desenvolvimento institucional que consolidam e valorizam esses espaços.                                                                   721
# Percebe-se que a sociedade reconhece a relevância e excelência do Complexo do Hospital de Clínicas na rede de serviços em saúde, reflexo de sua missão* e valores**.                                                                                                                                                                             700
# A missão* do Complexo do Hospital de Clínicas (CHC-UFPR/Ebserh) é coerente com as necessidades locais e regionais.                                                                                                                                                                                                                               695
# Coordenadoria do Hospital Veterinário                                                      209
# Unidade da Biblioteca de Ciências Biológicas                                               209
# Seção de Políticas Afirmativas, Assuntos Estudantis e Comunitários                         209
# Unidade de Apoio à Graduação e à Pós-Graduação                                             209
# Coordenadoria de Apoio e Prestação de Contas                                               209
# Unidade de Segurança, Riscos e Governança de TIC                                           208
# Serviço Pronto Atendimento Adulto                                                          208
# Seção de Planejamento e Gestão                                                             208
# Assessoria de Gestão de Qualidade                                                          208
# Departamento de Medicina Veterinária                                                       208
# Seção de Processo Técnico                                                                  208
# TRANSPLANTE DE MEDULA OSSEA -EXTINTO (extinta)                                             208
# Seção Fisioterapia                                                                         208
# Unidade da Biblioteca do Campus Rebouças                                                   208
# Unidade da Biblioteca de Ciências da Saúde/Botânico                                        207
# Departamento de Saúde Coletiva                                                             207
# Unidade da Biblioteca do Centro de Estudos do Mar                                          207
# Coordenadoria de Acompanhamento de Contratos e Serviços Terceirizados                      207
# Departamento de Prevenção e Reabilitação em Fisioterapia                                   206
# Departamento de Química                                                                    205
# Coordenadoria de Parcerias                                                                 204
# Unidade da Biblioteca de Ciência e Tecnologia                                              203
# Departamento de História                                                                   200
# Seção de Design e Comunicação Visual                                                       192
# Departamento de Zoologia                                                                   190
# Departamento de Construção Civil                                                           189
# Departamento de Clínica Médica                                                             178
# Departamento de Planejamento e Administração Escolar                                       176
# Departamento de Engenharia de Produção                                                     174
# Departamento de Geografia                                                                  140
# Seção de Grupos Artísticos                                                                 140
# Departamento de Teoria e Prática de Ensino                                                 140
# Serviço Métodos Neurológicos                                                               140
# Seção de Imunoquímica                                                                      140
# Seção de Gerenciamento Acadêmico                                                           140
# Unidade de Suprimentos                                                                     140
# Departamento de Engenharia e Tecnologia Florestal                                          140
# Biblioteca de Ciências Sociais Aplicadas (extinta)                                         140
# Seção de Internacionalização na Pós Graduação                                              140
# Unidade de Apoio                                                                           140
# Departamento de Expressão Gráfica                                                          140
# Serviço Métodos Cardiológicos                                                              140
# Departamento de Turismo                                                                    139
# Seção de Gestão de Indicadores                                                             139
# Seção de Central de Serviço e Atendimento em TIC                                           139
# Seção de Serviços de Limpeza                                                               139
# Setor de Ciências Humanas                                                                  139
# Seção de Comissões Disciplinares                                                           139
# Unidade de Convênios e Saúde Complementar                                                  139
# Serviço Enfermagem Neonatologia e UTI Neonatal                                             139
# Unidade da Biblioteca de Artes, Comunicação e Design                                       139
# Unidade de Liquidação                                                                      139
# Unidade da Biblioteca de Ciências Jurídicas                                                139
# Departamento de Transportes                                                                139
# Serviço de Nutrição Clínica                                                                139
# Seção de Currículo                                                                         139
# Seção de Cadastro de Bens Móveis                                                           138
# Serviço de Doenças Neuromusculares                                                         138
# Seção de Tecnologia da Informação                                                          138
# Seção do Centro Atenção à Saúde 4                                                          138
# Seção Virologia                                                                            138
#  Coordenadoria de Orçamento, Administração e Gestão                                        138
# Seção de Apoio a Tecnologia da Informação                                                  137
# Departamento de Literatura e Linguística                                                   137
# Seção de Apoio a Publicações Científicas Periódicas                                         69
# Unidade de Apoio à Governança e à Gestão de Riscos                                          69
# Seção de Saúde e Segurança Ocupacional, Acessibilidade e Apoio Administrativo               69
# Seção de Acompanhamento Acadêmico                                                           69
# Seção de Museologia, Ações Educativas e Difusão Cultural                                    69
# Central de Atendimento ao Servidor (extinta)                                                69
# Seção de Apoio ao Estudante                                                                 69
# BIBLIOTECA DA ESCOLA TECNICA DA UFPR - EXTINTO (extinta)                                    69
# Coordenadoria de Acessibilidade                                                             69
# Biblioteca Central                                                                          69
# Secretaria Acadêmica da Graduação                                                           68
# Seção de Expediente e Tecnologia da Informação                                              68
# Coordenação do Curso de Engenharia Industrial Madeireira                                    68
# Departamento de Educação, Ensino e Ciências                                                 68
# Coordenadoria de Contabilidade                                                              68
# Seção de Serviços de Portaria, Vigia e Recepção                                             68
# Unidade de Apoio Administratrivo                                                            68
# Unidade da Biblioteca de Ciências Agrárias                                                  68
# DEPARTAMENTO DE LETRAS ESTRANG MODERNAS (extinta)                                           68
# DEPTO DE LINGUISTICA LETRAS CLAS E VERN (extinta)                                           67
# Unidade de Gestão Administrativa e Orçamentária                                             66
# Seção Centro Mat.Esterilizado Centro Cirúrgico                                              63
# Unidade de Creditação da Extensão                                                           62
# Centro de Estudos do Mar                                                                    62
# Diretoria de Desenvolvimento e Integração dos Campi                                         61
# Equipe Desenvolvimento do HC                                                                60
# Departamento de Ciência Política                                                            57
# DEPARTAMENTO DE BIBLIOTECONOMIA (extinta)                                                   50
# Unidade de Planejamento e Controle de Licitações                                            50
# Assessoria Técnica                                                                          50
# Coordenação do Programa de Pós-Graduação em Zoologia                                        50
# Departamento de Análises Clínicas                                                           49
# Unidade da Biblioteca do Campus Toledo                                                      48
# Coordenadoria de Projetos Pedagógicos e Análise de Currículo                                48
# Coordenação do Curso de Medicina                                                            47
# Departamento de Ciências Econômicas                                                         44
# Superintendência de Logística                                                               43
# PRO-REITORIA DE REC HUM E AS ESTUDANTIS (extinta)                                           39
# Unidade Diagnóstico por Imagem e Terapia p Radiação                                         39
# Unidade da Biblioteca de Ciências da Saúde                                                  32
# Unidade de Apoio da Procuradoria Federal                                                    21
# Gabinete do Reitor                                                                          21
#
#
# --- Frequência: SIGLA_LOTACAO ---
# SIGLA_LOTACAO
# BL/UAA               994
# SA/DAGA              918
# R/TL                 872
# SD/DFAR              818
# R/JA                 758
# TC/DEQ               746
# CAISS/POS            594
# CH/DELEM             554
# CPP/LT               466
# ET/DFIS              466
# R/PP                 460
# ET/DINF              454
# SA/DECONT            420
# SA/DECIGI            418
# R/EP                 412
# PL/DCA               396
# R/SD                 394
# SA/DEPECON           375
# TC/UAA               372
# ET/DEST              363
# BC/SIBI-CH           351
# CGA/SGAG             350
# BL/DPAT              349
# PROPLAD/CPROJ        349
# TC/DEA               348
# SD/DNUT              348
# BC/SIBI-JA           347
# R/SUCOM              347
# BC/SIBI-SA           347
# JD/SAPG              346
# PL/DBD               346
# R/LT                 344
# PL/DEE               342
# SD/DCIR              340
# BL/DBIOCEL           329
# BL/DBIOQ             322
# ET/DMAT              322
# BL/DBOT              309
# PROPLAD/CECD         280
# AG/DFF               280
# TC/DEBB              280
# SA/UAA               279
# AUDIN/UEX            279
# TC/DEMEC             279
# TC/DELT              278
# AGTIC/CSI            278
# R/HC                 278
# PP/GA                277
# CAISS/UST            276
# BC/SIBI-CF           275
# DD/SAT               275
# SD/DENF              270
# PROPG/UCEO           267
# AGTIC/CSGD           259
# BC/SIBI-PL           252
# BL/DFISIO            239
# PL/DBC               239
# TC/DHS               225
# GAB/PF               210
# BL/DGEN              210
# SD/DESTO             210
# CCIR                 210
# BL/DEDFIS            209
# CGA/SEPOL            209
# BC/SIBI-BL           209
# AG/UCEO              209
# ED/UAGPG             209
# PROAD/CAPC           209
# JA/UAA               209
# PL/HV                209
# JD/UAA               208
# BC/SIBI-RB           208
# AGTIC/GOVTIC         208
# AG/DMV               208
# BC/SPT               208
# SUPER/AGQ            208
# SMFR/FISIOTERAP      208
# UUEA/SPAA            208
# COEX/SEPLAG          208
# BC/SIBI-SB           207
# PROAD/CAAST          207
# BC/SIBI-PP           207
# SD/DSC               207
# BL/DPRF              206
# ET/DQUI              205
# SUPRI/CPAR           204
# BC/SIBI-CT           203
# CH/DEHIS             200
# TL/SAA               192
# SUCOM/SDCV           192
# BL/DZOO              190
# TC/DCC               189
# TC/UCEO              189
# BL/UCEO              189
# SD/DCM               178
# ED/DEPLAE            176
# SULOG/UAA            176
# TC/DEP               174
# BC/UAA               158
# UDITRA/SMNEUR        140
# SOC/UA               140
# AG/DETF              140
# COPAP/SGA            140
# COGES/USUP           140
# ET/DEGRAF            140
# CT/DGEOG             140
# UCP/SMCARD           140
# AG/UAA               140
# PROPG/SIPROP         140
# ED/DTPEN             140
# COC/SEGA             140
# UDITRA/IMQ           140
# AGTIC/CSA            139
# CAAST/SSL            139
# TC/DTT               139
# CAF/ULIQ             139
# UNICLIN/NUTRICLIN    139
# R/CH                 139
# CAISS/UCSS           139
# BC/SIBI-AC           139
# BC/SGI               139
# AG/DZ                139
# COPPAC/SCUR          139
# BC/SIBI-JD           139
# CH/DETUR             139
# DD/SCD               139
# UMRN/ENF2/3A         139
# JA/UAC               138
# TL/UCEO              138
# UNP/NEUROMUSC        138
# SACL/VIROLOGIA       138
# UPAT/SCBM            138
# P4E/COAG             138
# CAISS/CASA 4         138
# JA/STI               138
# BC/STI               137
# BC/UCEO              137
# CH/DELLIN            137
# TC/DAU               136
# HV/UCEO              135
# CSI/SATIC            133
# PL/UAAG              131
# CDP/UCAQ             130
# JD/SADG              124
# PL/UAAC              120
# RU/UNUT              120
# COGES/UARQ           120
# CLIC/UCON            119
# PL/DZO               119
# SD/DPM               111
# PROGRAP/COAPPE        98
# PROAD/UCEO            70
# PROAFE/CPI            70
# BC/SCM                70
# SUPRI/CPROP           70
# R/SUPRI               70
# PROGRAP/UCEO          70
# SD/DOR                70
# CCE/DRD               70
# ET/UAL                70
# UMRN/ENF5A            70
# PROPLAD/CPDI          70
# UUEA/CTSIADULTO       70
# PL/DCV                70
# CAISE/USBE            70
# COGES/UPAT            70
# CT/UAA                70
# CPAR/APOIO            70
# CH/DEAN               70
# ED/DTFE               70
# SUPER/DMHC            70
# R/PRA                 70
# PROPG/CPGSS           70
# BL/DANAT              70
# SD/DTO                70
# AG/HV                 70
# SUPRI/UAA             70
# CT/CCGEOG             70
# PROPLAD/CETIC         70
# COPAP/UDIP            70
# CDP/SAT               70
# JA/UCEO               70
# CGA/SGP               70
# SIHOSP/REC            70
# PROGEPE/CDP           70
# BC/SFDA               70
# NIT/UPAI              70
# SACL/IMUNOGENET       70
# BL/ASPEC              70
# CPOR/UGP              70
# AC/DECOM              70
# AC/DEARTES            70
# CPROJ/UOC             70
# CH/UAAP               70
# CCONT/UAC             70
# DAP/URFC              70
# HV/SCEO               70
# JD/DDPUB              70
# PROAFE/CPC            70
# UFH/QUALIDADE         70
# GAB/ERI               70
# SULOG/COGES           70
# BC/SAU                70
# PRA/CECOM             70
# BL/DFARM              70
# SD/UAA                70
# CIED/SEAD             70
# SEADIP/UCEO           70
# CDP/SAV               70
# PRPPG/CPGSS           70
# OUV/SAA               70
# DAR                   70
# AUDIN/SAA             70
# PROEC/COC             70
# AUDIN/UMA             70
# CH/DELI               70
# CT/PPGG               70
# GAS/UND               70
# SD                    70
# BC/SIBI-EP            70
# MAE/SCP               70
# SD/CCTO               70
# BL/CED                70
# BL                    70
# CPROJ/SGA             70
# SACL/PMR              70
# CPAR/ACORDOS          70
# GAB/SOC               70
# CH/DEPSI              70
# BL/PGECO              70
# GAS/UNIMULTI          70
# CAF/UPAG              70
# P4E/CP3DE             70
# CP3DE/UACOMP          70
# CAISS/CASA 3          70
# PROGRAP/COPAE         70
# PRPI/COPI             70
# R/AG                  70
# CPP/URP               70
# EP/STE                70
# AG/DERE               70
# EP/SAAD               70
# SEADIP/CIED           70
# PROEC/UCEO            69
# CMA/SAMP              69
# ET/UAA                69
# PROPG/UDC             69
# PL/UCEO               69
# AUDIN/SAE             69
# CEEX/FC               69
# PROGEPE/CPP           69
# JD/DDPRIV             69
# BC/SAP                69
# PROAFE/CAS            69
# JD/NPJ                69
# PROGEPE/CAS           69
# JA/SSAA               69
# CAAST/SGC             69
# COPAP/SAAC            69
# R/BC                  69
# PROAD/CPCO            69
# UAMB/SPSICO           69
# SAP/MICROSCOPI        69
# CAAST/SSV             69
# MAE/SMAD              69
# PROPG/SAE             69
# CMA/ALMOX             69
# PRHAE                 69
# BL/PGBCM              69
# PL/SMAO               69
# UNIMULTI/SMFR         69
# UAMB/ENFAMBULAT       69
# SACL/BACTERIOL        69
# CAF/UEMP              69
# SCIH                  69
# PROGEPE/SCA           69
# SUCOM/CPAUD           69
# ED/COOPED             69
# CPDI/UGR              69
# CGA/SGAPG             69
# SUPRI/CPOR            69
# PL/SACG               68
# PROGEPE/UAA           68
# PL/SETI               68
# PROAD/CCONT           68
# CAAST/SSP             68
# PL/DEC                68
# BC/SIBI-AG            68
# AG/CCEIM              68
# PROAFE/UAA            67
# DDI/UAO               66
# CME-CC                63
# R/CEM                 62
# COEX/UCRED            62
# GAB/DDI               61
# DESENVOL              60
# CH/DECP               57
# SA/UCEO               53
# PROPG/UAA             51
# GAB/ASS               50
# CLIC/UPCL             50
# PROEC/UAA             50
# BL/PGZOO              50
# SD/DAC                49
# PROGRAP/COPPAC        48
# BC/SIBI-TL            48
# TL/CMEDT              47
# SA/DE                 44
# R/SULOG               43
# CSA/UDITRA            39
# R/PRHAE               39
# BC/SIBI-SD            32
# PF/UAA                21
# R                     21

# %% [markdown]
# ## 3. Verificação de possíveis dados na tabela principal

# %% [markdown]
# Nesta parte, traremos informações relevantes para uma única tabelas (em torno da tabela `df_dados_pesquisa`).
#
# Aqui veremos a relação de cada tabela com a nossa principal.

# %% [markdown]
# ### 3.1 Info_Perguntas e Info_Questionários

# %% [markdown]
# ---

# %%
df_dados_info_perguntas_raw = remove_unnamed_columns(df_dados_info_perguntas_raw)
df_dados_info_perguntas_raw
# Out:
#     Tipo_Perg                                 Grupo_de_Perguntas
# 0     MsãoPDI    Missão e Plano de Desenvolvimento Institucional
# 1        RsSc                            Responsabilidade Social
# 2      PolPes                               Políticas de Pessoal
# 3  OrgGesInst                Organização e Gestão da Instituição
# 4     SustFin                        Sustentabilidade Financeira
# 5         CHC  Complexo do Hospital de Clínicas (CHC-UFPR/Ebs...

# %% [markdown]
# Talvez seja uma boa ideia trazer o `Tipo_Perg` para a tabela principal, pois tornaria mais fácil a visualização da distribuição de respostas na tabela principal.

# %% [markdown]
# ---

# %%
df_dados_info_questionarios_raw = remove_unnamed_columns(df_dados_info_questionarios_raw)
df_dados_info_questionarios_raw
# Out:
#    ID_QUESTIONARIO                                       QUESTIONARIO
# 0              644    Missão e Plano de Desenvolvimento Institucional
# 1              645                            Responsabilidade Social
# 2              646                               Políticas de Pessoal
# 3              647                Organização e Gestão da Instituição
# 4              648                        Sustentabilidade Financeira
# 5              649  Complexo do Hospital de Clínicas (CHC-UFPR/Ebs...

# %% [markdown]
# Ambas as informações já estão na tabela principal.

# %% [markdown]
# ### 3.2 Unidades

# %%
df_dados_unidades_raw
# Out:
#        SIGLA_LOTACAO                       UNIDADE GESTORA  \
# 0         AC/DEARTES  Setor de Artes, Comunicação e Design
# 1           AC/DECOM  Setor de Artes, Comunicação e Design
# 2           AG/CCEIM            Setor de Ciências Agrárias
# 3            AG/DERE            Setor de Ciências Agrárias
# 4            AG/DETF            Setor de Ciências Agrárias
# ..               ...                                   ...
# 310    UNIMULTI/SMFR                  Hospital de Clínicas
# 311    UNP/NEUROMUSC                  Hospital de Clínicas
# 312        UPAT/SCBM                  Hospital de Clínicas
# 313  UUEA/CTSIADULTO                  Hospital de Clínicas
# 314        UUEA/SPAA                  Hospital de Clínicas
#
#                                                LOTACAO
# 0                                Departamento de Artes
# 1                   Departamento de Comunicação Social
# 2    Coordenação do Curso de Engenharia Industrial ...
# 3            Departamento de Economia Rural e Extensão
# 4    Departamento de Engenharia e Tecnologia Florestal
# ..                                                 ...
# 310             Serviço Medicina Física e Reabilitação
# 311                 Serviço de Doenças Neuromusculares
# 312                   Seção de Cadastro de Bens Móveis
# 313            Centro de Terapia Semi Intensiva Adulto
# 314                  Serviço Pronto Atendimento Adulto
#
# [315 rows x 3 columns]

# %% [markdown]
# A única coluna que não aparece na tabela principal é a `UNIDADE GESTORA`

# %% [markdown]
# ---

# %% [markdown]
# ### 3.3 Perguntas

# %% [markdown]
# Colunas de `df_dados_perguntas_raw`:
# * `ID_PERGUNTA` - Está na tabela principal; Autoexplicativo
# * `ID_QUESTIONARIO` - Está na tabela principal; Autoexplicativo
# * `TITULO` - Está na tabela principal; Equivalente à `QUESTIONARIO`
# * `CL_PERGUNTA` - Não está na tabela principal;Todas as observações são `Institucional`
# * `Ordem` - Não está na tabela principal; Ordem das perguntas feitas em cada questionário
# * `Coluna1` - Não está na tabela principal; Equivalente à `Tipo_Perg` da tabela `df_dados_info_perguntas_raw`
# * `PERGUNTA` - Está na tabela principal; Autoexplicativo

# %% [markdown]
# ## 4. Merge

# %%
df_temp_info_perg = df_dados_info_perguntas_raw.rename(columns={'Grupo_de_Perguntas':'QUESTIONARIO'})

# %%
# Merge `Tipo_Perg` 
df_merged_institucional2025 = pd.merge(left=df_dados_pesquisa_raw,right=df_temp_info_perg,on='QUESTIONARIO',how='left')

# Merge `Unidade Gestora`
df_merged_institucional2025 = pd.merge(left=df_merged_institucional2025,right=df_dados_unidades_raw[['SIGLA_LOTACAO','UNIDADE GESTORA']],on='SIGLA_LOTACAO',how='left')

# Merge `Ordem`
df_merged_institucional2025 = pd.merge(left=df_merged_institucional2025,right=df_dados_perguntas_raw[['ID_PERGUNTA','Ordem']],on='ID_PERGUNTA',how='left')

df_merged_institucional2025
# Out:
#        ID_PESQUISA  ID_QUESTIONARIO  \
# 0            46962              644
# 1            46962              644
# 2            46962              644
# 3            46962              644
# 4            46962              644
# ...            ...              ...
# 50274        47904              649
# 50275        47904              649
# 50276        47904              649
# 50277        47904              649
# 50278        47904              649
#
#                                             QUESTIONARIO  ID_PERGUNTA  \
# 0        Missão e Plano de Desenvolvimento Institucional         1982
# 1        Missão e Plano de Desenvolvimento Institucional         1983
# 2        Missão e Plano de Desenvolvimento Institucional         1984
# 3        Missão e Plano de Desenvolvimento Institucional         1985
# 4        Missão e Plano de Desenvolvimento Institucional         1986
# ...                                                  ...          ...
# 50274  Complexo do Hospital de Clínicas (CHC-UFPR/Ebs...         2053
# 50275  Complexo do Hospital de Clínicas (CHC-UFPR/Ebs...         2054
# 50276  Complexo do Hospital de Clínicas (CHC-UFPR/Ebs...         2055
# 50277  Complexo do Hospital de Clínicas (CHC-UFPR/Ebs...         2056
# 50278  Complexo do Hospital de Clínicas (CHC-UFPR/Ebs...         2057
#
#                                                 PERGUNTA  RESPOSTA  \
# 0      A missão* da UFPR é coerente com as necessidad...  Concordo
# 1      Percebe-se que a sociedade reconhece a relevân...  Concordo
# 2      Enquanto servidor (docente ou técnico), tenho ...  Concordo
# 3      Percebo o envolvimento de diversos atores da u...  Concordo
# 4      Os objetivos estratégicos do Plano de Desenvol...  Concordo
# ...                                                  ...       ...
# 50274  A política de gestão da qualidade e segurança ...  Concordo
# 50275  É perceptível a adesão, de modo geral, dos pro...  Concordo
# 50276  O Programa Ebserh de Gestão da Qualidade está ...  Concordo
# 50277  As políticas de controle orçamentário e de alo...  Concordo
# 50278  Os processos de compras e contratações no Comp...  Concordo
#
#             SITUACAO                        LOTACAO SIGLA_LOTACAO Tipo_Perg  \
# 0      Fim respostas             Assessoria Técnica       GAB/ASS   MsãoPDI
# 1      Fim respostas             Assessoria Técnica       GAB/ASS   MsãoPDI
# 2      Fim respostas             Assessoria Técnica       GAB/ASS   MsãoPDI
# 3      Fim respostas             Assessoria Técnica       GAB/ASS   MsãoPDI
# 4      Fim respostas             Assessoria Técnica       GAB/ASS   MsãoPDI
# ...              ...                            ...           ...       ...
# 50274  Fim respostas  Serviço Métodos Cardiológicos    UCP/SMCARD       CHC
# 50275  Fim respostas  Serviço Métodos Cardiológicos    UCP/SMCARD       CHC
# 50276  Fim respostas  Serviço Métodos Cardiológicos    UCP/SMCARD       CHC
# 50277  Fim respostas  Serviço Métodos Cardiológicos    UCP/SMCARD       CHC
# 50278  Fim respostas  Serviço Métodos Cardiológicos    UCP/SMCARD       CHC
#
#             UNIDADE GESTORA  Ordem
# 0      Gabinete da Reitoria    1.0
# 1      Gabinete da Reitoria    2.0
# 2      Gabinete da Reitoria    3.0
# 3      Gabinete da Reitoria    4.0
# 4      Gabinete da Reitoria    5.0
# ...                     ...    ...
# 50274  Hospital de Clínicas   71.0
# 50275  Hospital de Clínicas   72.0
# 50276  Hospital de Clínicas   73.0
# 50277  Hospital de Clínicas    NaN
# 50278  Hospital de Clínicas   74.0
#
# [50279 rows x 12 columns]

# %%
df = df_merged_institucional2025
df['RESPOSTA'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='RESPOSTA'>

# %% [markdown]
# Todos esses dados faltantes estão na mesma pergunta cujo `ID` é 2056. Portanto, iremos incrementar e inserir a ordem correta (74) .

# %%
df_merged_institucional2025.loc[df_merged_institucional2025['Ordem'] > 73, 'Ordem'] += 1
df_merged_institucional2025['Ordem'] = df_merged_institucional2025['Ordem'].fillna(74)

# %% [markdown]
# ## 5. Visualização de Dados

# %%
import textwrap

def plot_data_dist(df: pd.DataFrame, column: str) -> plt.Figure:

    values = df[column].value_counts().sort_values(ascending=True)
    
    labels_quebrados = [textwrap.fill(label, width=30) for label in values.index.astype(str)]

    altura_figura = max(5, len(values) * 0.5)
    
    fig, ax = plt.subplots(figsize=(10, altura_figura))

    ax.barh(labels_quebrados, values.values, color='skyblue')

    # 5. ESTÉTICA
    ax.set_title(f"Distribuição: {column}", fontsize=14)
    ax.set_xlabel("Contagem") # No barh, o X é a contagem

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    ax.grid(axis='x', linestyle='--', alpha=0.7)

    plt.tight_layout()

    plt.close(fig)
    return fig

# %%
def plot_distribuicao_numerica(df, coluna):
    fig, ax = plt.subplots(figsize=(10, 6))
    
    # histplot combina as barras com a linha de densidade (kde=True)
    sns.histplot(df[coluna], kde=True, bins=30, color='blue', ax=ax)
    
    # Linhas verticais para Média e Mediana (ajuda a ver assimetria)
    ax.axvline(df[coluna].mean(), color='red', linestyle='--', label='Média')
    ax.axvline(df[coluna].median(), color='green', linestyle='-', label='Mediana')
    
    ax.set_title(f"Distribuição de {coluna}")
    ax.legend()
    plt.close()
    return fig

# %%
plot_distribuicao_numerica(df_merged_institucional2025,'ID_PERGUNTA')

# %% [markdown]
# ## 6. Limpeza dos Dados

# %%
# Removendo dados com a resposta diferente do padrão
results = ['Concordo','Discordo','Desconheço']
df_merged_institucional2025 = df_merged_institucional2025[df_merged_institucional2025['RESPOSTA'].isin(results)]
temp_fig = plot_data_dist(df_merged_institucional2025,'RESPOSTA')
temp_fig.savefig('./temp_images/RESPOSTA_after')

# %%
# Remove missings  e duplicates
print('Antes de remover os missings: ')
print(df_merged_institucional2025.shape)
print('\nApós remover os missings: ')
df_merged_institucional2025.dropna().drop_duplicates()
print(df_merged_institucional2025.shape)
# Out:
# Antes de remover os missings:
# (50273, 12)
#
# Após remover os missings:
# (50273, 12)

# %%
df_merged_institucional2025.head(4)
# Out:
#    ID_PESQUISA  ID_QUESTIONARIO  \
# 0        46962              644
# 1        46962              644
# 2        46962              644
# 3        46962              644
#
#                                       QUESTIONARIO  ID_PERGUNTA  \
# 0  Missão e Plano de Desenvolvimento Institucional         1982
# 1  Missão e Plano de Desenvolvimento Institucional         1983
# 2  Missão e Plano de Desenvolvimento Institucional         1984
# 3  Missão e Plano de Desenvolvimento Institucional         1985
#
#                                             PERGUNTA  RESPOSTA       SITUACAO  \
# 0  A missão* da UFPR é coerente com as necessidad...  Concordo  Fim respostas
# 1  Percebe-se que a sociedade reconhece a relevân...  Concordo  Fim respostas
# 2  Enquanto servidor (docente ou técnico), tenho ...  Concordo  Fim respostas
# 3  Percebo o envolvimento de diversos atores da u...  Concordo  Fim respostas
#
#               LOTACAO SIGLA_LOTACAO Tipo_Perg       UNIDADE GESTORA  Ordem
# 0  Assessoria Técnica       GAB/ASS   MsãoPDI  Gabinete da Reitoria    1.0
# 1  Assessoria Técnica       GAB/ASS   MsãoPDI  Gabinete da Reitoria    2.0
# 2  Assessoria Técnica       GAB/ASS   MsãoPDI  Gabinete da Reitoria    3.0
# 3  Assessoria Técnica       GAB/ASS   MsãoPDI  Gabinete da Reitoria    4.0

# %% [markdown]
# ## 7. Processando os Dados

# %% [markdown]
# ### 7.1 Funções

# %%
possible_axis_global = {'PLANEJAMENTO_E_AVALIACAO_INSTITUCIONAL':[],
                    'DESENVOLVIMENTO_INSTITUCIONAL':['MsãoPDI','RsSc'],
                    'POLITICAS_ACADEMICAS':[],
                    'POLITICAS_DE_GESTAO':['PolPes','OrgGesInst','SustFin'],
                    'INFRAESTUTURA_FISICA':[],
                    'COMPLEXO_DO_HOSPITAL_DE_CLINICAS':['CHC']}

# %%
def add_axis(df: pd.DataFrame) -> (pd.DataFrame):
    possible_axis = globals().get('possible_axis_global',None)
    
    df = df.copy()
    
    mapa_de_para = {}
    if possible_axis is not None:
        for eixo, lista_tags in possible_axis.items():
            for tag in lista_tags:
                mapa_de_para[tag] = eixo

    df['EIXO'] = df['Tipo_Perg'].map(mapa_de_para)

    return df

# %%
def get_questions(df: pd.DataFrame, dimension:List[str] | None) -> (List[str]):
    possible_axis = globals().get('possible_axis_global',None) 
    global df_dados_perguntas_raw

    if dimension is None or dimension == []:
        dimension = []
        if possible_axis is not None:
            for i in possible_axis.keys():
                for j in possible_axis[i]:
                    dimension.append(j)

    mask = df['Tipo_Perg'].isin(dimension)

    df_filtered = df[mask]

    questions = df_filtered['PERGUNTA'].unique().tolist()
    return questions

# %%
def process(df: pd.DataFrame, axis: List[str] | None = None, dimensions:List[str] | None = None, questions:List[str] | None = None) -> (pd.DataFrame,List[str]):
    
    global df_dados_perguntas_raw
    possible_axis = globals().get('possible_axis_global',None)
    
    if possible_axis is not None:
        if axis is None or axis == []:
            
            axis = possible_axis.keys()
        
        if dimensions is None or dimensions == []:
            dimensions = []
            for i in possible_axis.keys():
                for j in possible_axis[i]:
                    dimensions.append(j)

        mask_axis = df['EIXO'].isin(axis)
        mask_dim = df['Tipo_Perg'].isin(dimensions)

        df_filtered = df[mask_axis & mask_dim]

        if questions is not None:
            df_filtered = df_filtered[df_filtered['PERGUNTA'].isin(questions)]

        return (df_filtered,get_questions(df,dimension=dimensions))

# %% [markdown]
# ### 7.2 Processamento

# %%
new_order = ['EIXO',
            'Tipo_Perg',
            'ID_PESQUISA',
            'ID_QUESTIONARIO',
            'QUESTIONARIO',
            'ID_PERGUNTA',
            'PERGUNTA',
            'RESPOSTA',
            'SITUACAO',
            'LOTACAO',
            'SIGLA_LOTACAO',
            'UNIDADE GESTORA',
            'Ordem',
            ]

# Add Axis
df_merged_institucional2025 = add_axis(df_merged_institucional2025)

# Process and order columns
df_final_institucional2025 = process(df=df_merged_institucional2025[new_order],axis=[],dimensions=[])[0]
print(df_final_institucional2025.shape)
df_final_institucional2025.head(2)
# Out:
# (50273, 13)
#                             EIXO Tipo_Perg  ID_PESQUISA  ID_QUESTIONARIO  \
# 0  DESENVOLVIMENTO_INSTITUCIONAL   MsãoPDI        46962              644
# 1  DESENVOLVIMENTO_INSTITUCIONAL   MsãoPDI        46962              644
#
#                                       QUESTIONARIO  ID_PERGUNTA  \
# 0  Missão e Plano de Desenvolvimento Institucional         1982
# 1  Missão e Plano de Desenvolvimento Institucional         1983
#
#                                             PERGUNTA  RESPOSTA       SITUACAO  \
# 0  A missão* da UFPR é coerente com as necessidad...  Concordo  Fim respostas
# 1  Percebe-se que a sociedade reconhece a relevân...  Concordo  Fim respostas
#
#               LOTACAO SIGLA_LOTACAO       UNIDADE GESTORA  Ordem
# 0  Assessoria Técnica       GAB/ASS  Gabinete da Reitoria    1.0
# 1  Assessoria Técnica       GAB/ASS  Gabinete da Reitoria    2.0

# %%
df_final_institucional2025.to_csv('processed_Institucional_2025.csv')
